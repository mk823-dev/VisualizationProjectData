# %% [markdown]
# # Introduction
#
# |Description|Link|
# | -- | -- |
# | Reflective blog | Insert Link here |
# | Chosen Dataset| https://www.kaggle.com/code/zabihullah18/data-science-salary-trend/input?select=Data+Science+Salary+2021+to+2023.csv, https://www.wtwco.com/en-gb/insights/2023/01/2023-employee-pay-trends#:~:text=And%20in%20the%2015%20largest,%25)%20and%20China%20(6.0%25). |
#
#
#
# ## Data visualization of salary trends accross the globe
#
# In this data visualization project, our primary objective is to dissect the global salary trends, with a particular emphasis
# on the distribution of salaries across various occupations and the compensation packages offered by diverse organizations.
# We will delve into the intricacies of roles and profiles, experience levels, geographical location of companies,
# and the overall reputation of the organizations.Our exploration will extend to understanding how different companies are
# navigating the evolving salary trends. This will involve an in-depth analysis of their strategic planning, budget allocations,
# and discussions with top-level executives such as HR personnel, COOs, CEOs, and Managers. By Leveraging advanced data
# visualization techniques, we aim to present these complex datasets in an easily digestible format. This will not only aid in
# comprehending the current state of global salary trends but also provide insights into the strategic decisions
# made by organizations in response to these trends. Whether you’re a data scientist aiming to communicate your findings
# effectively, a professional seeking to understand the salary landscape in your field, or a decision-maker in an organization,
# this exploration promises to offer valuable insights.

# %% [markdown]
# ## Background of this project and main objectives
#
# 1. <b>Understanding the salary trends:</b> It is a subject that both business owners and human resource departments struggle with:
#     are we paying our employees fairly? This includes not just fair compensation for various jobs within an organization,
#     but also how pay compares to other organizations in the same sector and geography. As a result, pay benchmarks are
#     established to ensure that payment systems are both logical and competitive. Because even the strongest hiring and
#     retention methods may be significantly harmed by salaries that are out of step with market rates. A benchmark is a vital
#     component in examining and constructing pay structures. It provides organizations with information on how competitors pay
#     their staff, allowing them to make sure that the payment they offer is competitive. The bottom line lies in establishing a
#     system of salaries that is comparable to those given by other similar organizations helps corporations recruit and retain
#     talented people.
# <br>
#
# 2.  <b>Data Sources:</b> The data sources which will be used in this project are secondary data. No primary data was collected for this project. The data is available for free on kaggle and other public databases. These datasets provide accurate insights on the salary trends.
# <br>
#
# 3. <b>Data Analysis Techniques:</b> We will be analysing various patterns by looking at different graphical representations, data cleaning, analysing tables by using python libraries like pandas, numpy, matplotlib and seaborn.
# <br>
#
# 4. <b>Project Goals:</b> The goal of this project is to evaluate the provided dataset, understand the wage patterns, learn more about
#     how HR and management make choices about staff compensation standards. How do they differentiate themselves in a
#     competitive market, and how do they strive to retain people and recruit fresh talent.

# %% [markdown]
# # Datasets
#
# ### 1 - Describing the dataset.
#
# ##### This dataset describes the latest salary trends from 2021 to 2023.
#
# <table style="width: 100%; border-collapse: collapse;">
#   <thead>
#     <tr>
#       <th>No</th>
#       <th>Column Name</th>
#       <th>Meaning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>work_year</td>
#       <td>Representing the specific year of salary data collection.</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Experience_level</td>
#       <td>The level of work experience of the employees, categorized as EN (Entry-Level), EX (Experienced), MI (Mid-Level), SE (Senior).</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Employment_type</td>
#       <td>The type of employment, labelled as FT (Full-Time), CT (Contractor), FL (Freelancer), PT (Part-Time).</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Job_title</td>
#       <td>The job titles of the employees, such as "Applied Scientist", "Data Quality Analyst", etc.</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Salary</td>
#       <td>The salary figures in their respective currency formats <b>(these are the annual packages not monthly)</b>.</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Salary_currency</td>
#       <td>The currency code representing the salary.</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Salary_in_usd</td>
#       <td>The converted salary figures in USD for uniform comparison.</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>Company_location</td>
#       <td>The location of the companies, specified as country codes (e.g., "US" for the United States and "NG" for Nigeria).</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Company_size</td>
#       <td>The size of the companies, classified as "L" (Large), "M" (Medium), and "S" (Small).</td>
#     </tr>
#   </tbody>
# </table>
#
#
# #### The second dataset compares the salary budgets of various organizations present cumulatively accross the 15 biggest global economies in the world and compares the actual data from 2021 and 2022 and then comparies it with 2023 projections.
#
# <table style="width: 100%; border-collapse: collapse;">
#   <thead>
#     <tr>
#       <th>No</th>
#       <th>Column Name</th>
#       <th>Meaning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Category</td>
#       <td>Represents the country.</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2021 Actual</td>
#       <td>Represents the actual percentage increase in the salary budgets in 2021</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2022 Actual</td>
#       <td>Represents the actual percentage increase in the salary budgets in 2021</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2. Important libraries used
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 3. Loading the Dataset
#
# Here, I have uploaded all the datasets to my github repository and made it available for public use. This file can be accessed globally.
#
# https://raw.githubusercontent.com/mk823-dev/VisualizationProjectData/main/Data%20Science%20Salary%202021%20to%202023.csv
#
# ![image.png](attachment:image.png)
#
# For the second dataset,
#
# ![image-2.png](attachment:image-2.png)
#
# https://raw.githubusercontent.com/mk823-dev/VisualizationProjectData/main/figure-1-average-salary-wtwco.com.csv

# %% [markdown]
# ### 4. Data Cleaning
#
# After checking all the data info using df.info() function.
#
# ![image-3.png](attachment:image-3.png)
#
# The data statistics using df.describe() function.
#
# ![image-4.png](attachment:image-4.png)
#
# and if there are null values or not using df.isnull().sum() function, we replace the unwanted values and clean the data.
#
# ![image-5.png](attachment:image-5.png)
#
#
# ![image.png](attachment:image.png)
#
# This is the table we get after the code execution:
#
# ![image-2.png](attachment:image-2.png)
#
#
# The second dataset does not have many contents on the file for data cleaning, it only contains the data for 15 countries.
#
# ![image-6.png](attachment:image-6.png)
#
# The data does not contain any null values.
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# # Project Dashboard
#
# These visualizations are significant in elements of the analysis since we will be focused on the main values data in the dataset. It is critical to examine the comparisons and analyses on numerous parameters included in the dataset, such as firm location, pay, work experience, and job title. According to the data in the dataset, the results are correct.
#
#
# ### 1. Salary Trends over Time
#
# Here in this line plot, the graph demonstrates the trend of wages in USD over time. The x-axis represents the work year, which runs from 2020 to 2023, while the y-axis represents the revenue in USD. The line represents the pay trends. It begins around 90,000 USD in 2020 and continues to rise, reaching over 150,000 USD in 2023. This shows that wages have risen significantly throughout this time period.
#
# ![image.png](attachment:image.png)
#
# Based on the statistics, we can conclude that the higher tendency is attributable to a variety of variables such as inflation, greater demand for certain abilities, or sector expansion. We can see that the graph is stable form 2020 to 2021 due to COVID-19 and sees a sudden spike after 2021 as the businesses open and demand increased.
#
# ##### Code:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2. Salary Trends Over Time by Company Size
#
# It's a line graph with the year worked on the x-axis and the salary in USD on the y-axis. On the graph, three lines depict different firm sizes: large (blue), medium (green), and small (teal) which demonstrates that salaries for major enterprises have risen over time, whereas salaries for medium and small businesses have stayed relatively consistent. The shaded region beneath each line reflects the salary range for each firm size.
#
#
# ![image-2.png](attachment:image-2.png)
#
# Furthermore, we can observe that larger organizations tend to give higher compensation and have witnessed greater salary increase over time than medium and small enterprises.
#
# ##### Code:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 3. Average Salary by Experience Level
#
#
# In this line plot, the x-axis shows the average wage in USD, while the y-axis shows the amount of experience. The graph has three bars, each reflecting a distinct degree of experience: entry-level (blue), mid-level (green), and senior (purple).
#
# As indicated in the graph, the following are the average earnings for each experience level:
#
# Starting Salary: 78,546.26 USD
# Mid-senior Level: 104,544.66 USD
# Senior Level: 193,403.93 USD
#
#
# ![image.png](attachment:image.png)
#
# Furthermore, Salary increases with experience level are a frequent trend in many sectors, since more experienced individuals often have a better degree of skill and can handle more complicated jobs.
#
# ##### Code:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4. Average Salary by Employement Type
#
#
# In this bar graph, the x-axis depicts several employment types like contractor, freelancer, full-time, and part-time. The average wage in USD is represented on the y-axis. According to the graph, Full-time workers have the greatest average income, followed by contractors, freelancers, and part-time employees.
#
# Here are the average salaries for each employment type as shown on the graph:
#
# Contractor: 113,449.85 USD
# Freelancer: 51,807.8 USD
# Full-Time: 139,267.64 USD
# Part-Time: 39,353.71 USD
#
# ![image.png](attachment:image.png)
#
# Based on the information available, one could decide that full-time and contract positions often pay more than freelancing and part-time positions. This might be because of a number of variables, such as the amount of hours spent, the type of the task, plus the level of expertise necessary.
#
# ##### Code:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 5. Average Salary by Currency
#
#
# Based on the data, it is possible to conclude that the average pay varies greatly depending on the currency, which might indicate disparities in economic conditions, cost of living, and wage levels among nations.
#
# ![image.png](attachment:image.png)
#
# Employees paid in USD have the highest average wage, which is around 149,351 USD.
#
# Salaries in ILS (Israeli Shekel) are notable, with an average salary of 423,834 USD.
#
# Average wages in GBP (British Pound) and CHF (Swiss Franc) are similarly competitive.
#
# Average salaries in other currencies vary, with the AUD (Australian Dollar) and BRL (Brazilian Real) being among the lowest.
#
# ##### Code:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 6. Salary Distribution by Location
#
#
# Based on the data, we can conclude that the average pay varies greatly depending on the currency, which might indicate disparities in economic conditions, cost of living, and wage levels among nations.
#
# ![image.png](attachment:image.png)
#
#
# ##### Code:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Analyzing the Salary Budgets Accross the Globe
#
# The graph is a bar chart named "Average salary increase budgets for the 15 largest economies for 2021 and 2022." It compares average wage increase budgets for 2021 and 2022 in 15 countries. Australia, Brazil, Canada, China, France, Germany, India, Italy, Japan, Mexico, Russia, South Korea, Spain, the United Kingdom, and the United States are among them.
#
# The percentage increase in salary budgets ranges from 0% to 8% on the y-axis. The nations are listed on the x-axis. Each nation has two bars on the graph, one for 2021 (colored purple) and one for 2022 (colored pink).
#
# ![image.png](attachment:image.png)
#
# For this bar graph plot, I have created this using dash python.
#
# <a href="https://raw.githubusercontent.com/mk823-dev/VisualizationProjectData/main/figure-1-average-salary-wtwco.com.csv" rel="noopener noreferrer">Dataset link</a>
#
# Here, if we see closely at the European countries and United states, salary increases have stayed between 1% to 1.5% and the overall average real wage rise in 2022 is 5.0%, up from 4.0% in 2021 across firms in the world's top 15 largest economies.India had the highest average salary in both 2021 8.7% and 2022 9.8%. Japan had the lowest average salary in 2021 2.3%, while Australia had the lowest in 2022 3.7%. Budgets in 2022 were 0.8% higher in Italy, 1.1% point higher in Germany, and 1.4 percentage point higher in Spain as compared to 2021. Following its recent exit from the European Union, the United Kingdom led the group by 1.5 percentage points in 2022 compared to 2021, with budget increases of 4.3% in 2022 vs 2.8% in 2021.
#
# Even the 1.0% increase from 2021 to 2022 is considerable in terms of firms overall pay cost. For some businesses, such an increase means millions of dollars in investment. This enhances the importance of businesses having a defined plan for giving pay raises as efficiently as feasible. It also entails moving beyond a one-size-fits-all approach to pay increases and requiring difference among nations, at-risk or vital talent, and a multi-factor strategy that goes beyond pay to optimize overall incentives.
#
# The most frequently mentioned causes for firms reporting larger 2022 actual salary budgets compared to 2021 budgets were:
#
# Pressures from inflation (79%).
# Concerns about a labor shortage (48%).
# Attempts to increase retention (37%).
#
# #### Analysing the average salary budget projections for 2023 by comparing percentage increase in July 2022 to December 2022
#
#
# In this Grpah, it compares the average pay increase budgets for 2021 and 2022 in seven nations. These countries are France, Germany, Italy, Mexico, Russia, Spain, the United Kingdom, and the United States. The percentage increase in salary budgets ranges from 0% to 8% on the y-axis. The nations are listed on the x-axis. Each country has two bars on the graph, one for 2021 (blue) and one for 2022 (dark blue).
#
#
# ![image-2.png](attachment:image-2.png)
#
# Based on the visual details, here are some observations:
#
# The average pay increase budget in the United States is roughly 8%.
# The average wage increase budget in Italy is roughly 2%.
# In most nations, the budget for wage increases in 2022 is bigger than in 2021, reflecting solid economic development and recovery.
#
# While it is customary for final raises for the year and predictions for the following year to alter over time as companies learn more about the variables influencing increases (e.g., unemployment, labor supply and demand), the shift is usually not this substantial. When companies planned for 2022, we noticed very minor adjustments in wage budget predictions for 2021. However, given that adjustments in compensation budgets frequently trail economic developments by 6 to 12 months, it appears that salary budgets are now catching up with labor market fundamentals.
#
# #### Analysing Salary Budgets for 2023
#
#
# In this graph, it compares the average salary increase budgets for the years 2021, 2022, and projected for 2023 across 15 countries.
#
#
#
# ![image-3.png](attachment:image-3.png)
#
# With an average pay rise budget of 8.7% in 2021, 9.8% in 2022, and a projected 10% in 2023, India has the largest average salary increase budget throughout all three years.
#
# Brazil is the only country with a projected decline in average salary but has a large budget for pay increases, with 7.1% in 2021 and 8.3% in 2022, however the prediction for 2023 is significantly lower at 7.5%.
#
# Russia's is expected to rise steadily from 5.9% in 2021 to 8.6% in 2023.
#
# On the low end, France, Germany, Italy, and Japan have pay rise budgets that are less than 3% in 2021, although all are expected to climb in the following years and China stays the same with no change at 6.0%.
#
# Budgets for pay increases in the United States and Canada are moderate, with a steady increase from 2021 to 2023 projected.
#
#
# #### Reasons assisting the salary proejctions for 2023
#
# Compensation and human resource experts will need to constantly evaluate labor markets and economic situations in 2023 and be flexible enough to move fast when necessary. Organizations in the 15 major economies expected 4.6% growth in 2023 in July 2022, but the December 2022 offers a different scenario, with 2023 estimates closer to 5.5%. This is nearly a full percentage point higher.
#
# Organizations are determining how to target their pay expenditure for the most benefit in order to overcome recurring problems. Though people demand greater compensation to help with the cost of living, as companies prepare for 2023, they must combine cost management with employee attraction and retention initiatives by adopting several activities to maintain employees actions that must go beyond pay increases alone.

# %% [markdown]
# # Future Scope and Decision Making process
#
#
# This chart compares the percentage of employers who will be recruiting for key roles in the next 12 months in different countries. These roles are in the fields of Information Technology, Engineering, and Sales.
#
# ![image.png](attachment:image.png)
#
# <a href="https://www.wtwco.com/en-ie/insights/2022/12/2023-pay-trends-across-industries" rel="noopener noreferrer">Image Source</a>
#
# With 67% of firms recruiting for employment in information technology, the United States leads the world.
# Brazil also has a high amount of firms hiring for Information Technology positions (58%).
#
# The United States and Brazil continue to lead in Engineering roles, with 50% and 48%, respectively.
#
# In comparison to the United States and Brazil, the United Kingdom has a somewhat smaller percentage of employers recruiting for employment in both disciplines.
#
# At 46%, Taiwan has the lowest percentage of firms recruiting for positions in information technology.
#
#
# #### The salary budget rise in 2022 was the greatest in nearly 20 years.
#
# Given the critical role that wage plays in an organization's capacity to recruit and retain people, employers want to continue with this increase until 2023, but they will be cautious about how and when they spend the entire budget.
#
# ![image-2.png](attachment:image-2.png) <a href="https://www.wtwco.com/en-ie/insights/2022/12/2023-pay-trends-across-industries" rel="noopener noreferrer">Image Source</a>
#
# This visual describes the measures performed by corporations in reaction to specific situations, probably connected compensation for employees.
#
# ![image-3.png](attachment:image-3.png)
# <a href="https://www.wtwco.com/en-ie/insights/2022/12/2023-pay-trends-across-industries" rel="noopener noreferrer">Image Source</a>
#
# 51% of businesses have reviewed certain employee demographics' remuneration. This might entail examining the pay of certain groups of employees to ensure they are competitive and equal.
#
# 45% of companies have introduced targeted raises for certain employee groups. This implies that these companies have designated specific groups of employees for compensation rises, maybe based on reasons such as performance, market demand for their abilities, or internal equality concerns.
#
# One-time cash rewards, such as retention bonuses, lump-sum payments, or allowances, were made by 44% of firms. These payments can be used to incentivise staff, reward performance, or solve employee retention issues.
#
#
# #### Visual Analysis for Recommended Job Titles for Entry Level Candidates
#
# This bar graph shows the recommended job titles for entry-level candidates with a salary range of $5000 to $80,000 USD.
#
# ![image-4.png](attachment:image-4.png)
#
# The x-axis shows the number of job opportunities, while the y-axis shows the job titles. The job title with the most counts is Data Analyst, which has 33. This implies that there are several entry-level possibilities in data analysis within the stated wage range.
#
# The second highest, with a count of 29, is Data Scientist, showing that this is also a typical entry-level position.
# Machine Learning Engineer and Business Intelligence Analyst are two more job titles with a high count, indicating that these sectors have a considerable number of entry-level chances.
#
# Automotive Vehicle Engineer has the fewest job titles on the graph.
#
# ##### Code:
#
# ![image-5.png](attachment:image-5.png)
#
# ### Trends that will influence incentive decisions in 2023
#
# Economic instability and uncertainty may result in reduced investment levels and economic development, forcing firms to reassess their workforces and be more careful about raising wages (among other things).
#
# Organizations will go beyond salary and consider complete incentives in order to build employee experiences that attract and retain the talent required to drive business objectives.
#
# Compensation and HR professionals will seek a more sophisticated knowledge and application of data in their strategic overall rewards practices and policies in order to compete effectively against industry rivals.
#
#
# ## Overall Salary Budget Data Analysis Summary
#
# Organizations require strategic strategies to connect pay hikes with company performance with larger compensation than 20 years ago. Salary increases should be transparent and linked to achievements. Budgets for pay hikes are shaped by a variety of macroeconomic factors—this is merely one component of overall compensation.
#
# A one-size-fits-all global raise policy ignores the unique circumstances of each country. To decide increases, countries should be classified according on economic factors, labor markets, and legislation. Pay raises may struggle to keep pace with unexpected inflation spikes—the length of price repercussions is important when times are unpredictable.
#
# In countries with lower inflation, increases may outpace inflation. Centralized bargaining nations or those with mandated indexing adhere to current norms for cost-related rises. Markets with historically high inflation require larger budgets as well as imaginative solutions such as targeted increases or one-time adjustments.
#
# Countries with hyperinflation of more than 30% require very different strategies. Increases in frequency, cost-of-living adjustments, or tying pay to stable foreign currencies all serve to protect buying power.
#
# The goal is to adjust pay rise techniques to the unique surroundings of each place. There is no single formula that works for all geographies experiencing varying economic shocks and policies. Customization contributes to the balance of employee purchasing power, corporate affordability, and market pay rates.
#
# Balance equality and retention by tailoring rewards. Workforce should be segmented based on level, performance, and important jobs. Budgets can be used to fix diversity gaps and retain excellent people. Consider one-time adjustments for lower-level employees or targeted raises for key personnel.
#
# Consider total incentives in addition to pay. Remember that bonuses, rewards, wellness, growth, and flexibility are all important. Enhance the experience, DEI initiatives, and work-life integration. Alternatively, you may go surgical with retention offers and extreme range modifications. The best ROI is obtained by prioritizing and segmenting all incentives.
#
# Education and communication are critical. Explain the differences between the cost of living and the cost of labor. Highlight the value of the whole compensation package, not just the basic wage. Salaries are significant fixed expenditures that must be managed carefully. Though inflation reduces purchasing power, wages never fall as prices do. Employees who use web statistics on "pay cuts" require fundamental economics and labor market courses. This outreach is essential.
#
# The essentials are to balance talent needs in segmented ways, promote the complete incentives experience, and effectively communicate market conditions to employees. This method efficiently meets the interests of numerous stakeholders.

# %% [markdown]
# # Visualization using other tools (if free choice given)
#
#
# This dashboard I created is from Salesforce Reports and Dashboards tool. This is an interactive dashboard which looks up at the report which contains the dataset I have described above (the latest salary trends from 2021 to 2023) which has total of 3761 records. First I uploaded the CSV file into a custom object which organizes the columns into field attributes, then I loaded the records into a report.
#
# ![image-4.png](attachment:image-4.png)
#
#
# This is how the report looks like. We can drag and drop any information and customise and add any kind of filters.
#
# ![image-5.png](attachment:image-5.png)
#
#
#
#
# ![image-3.png](attachment:image-3.png)
#
# This pie chart provides the same information as the above visualization describing the recommended job titles for entry-level candidates.
#
#
# ### 2. Average top Salaries by Location
#
#
# Here I have used scatter plot to describe the same visualization (Top Average Salaries by Location) above using python. In the dashboard, we can hover over the colored areas and see more details about the location and salary data related to that location.
#
# ![image-7.png](attachment:image-7.png)
#
#
# ### 3. Average Salary by Employment Type
#
# Here, I have used the same visualization which is a average salary by employement type above using python. In this dashboard, I have used a funnel chart and we can get more details after hovering over each funnel section.
#
# ![image-8.png](attachment:image-8.png)
#
#
# Report using which the dashboard is generated
#
# ![image-9.png](attachment:image-9.png)
#
# ## Advantages of using Salesforce Dashboards
#
# Salesforce dashboards are designed to aid in the identification of trends, the sorting of amounts, and the measurement of the effect of relevant operations. These dashboards also allow you to simply pinpoint what isn't working in order to correct it. Salesforce dashboards are extremely customisable, letting teams swiftly organize and evaluate data amounts because to their highly visible nature. You can use the same report in several dashboard components on a single dashboard. This is a method of consuming several reports with the same overall subject, but in a single, more digestible format. This all contributes to your team's ability to visualize and group data in order to make the best decisions.
#
# 1. Data Interpretation Visually Dashboards, like as those provided by Salesforce, give a method to handle the massive amounts of data we get on a regular basis. They convert various reports into visual components such as graphs, charts, tables, and metrics that can be seen on a single interface. This enables decision-makers to digest a great amount of critical information rapidly.
# <br>
#
# 2. Customizing Solutions to Your Specific Needs Salesforce dashboards may be totally customized to meet your specific business requirements. Users may change the display parameters to view only the data they desire, eliminating superfluous information.
# <br>
#
# 3. Data Reporting and Analysis in Real Time Because it removes delays between data receiving and reporting, real-time reporting has a considerable benefit over batch processing. This enables enterprises to act on the most up-to-date information, reducing the danger of relying on old data.
# <br>
#
# 4. Data Presentation Charts are an efficient method to show information. A dashboard may display data from custom source reports, manage data visibility based on the running user, present data as of the latest dashboard refresh, and schedule data to be automatically refreshed and emailed.
# <br>
#
# 5. Cloud-based Instant Deployment and Universal Access Cloud-based analytics dashboards operate directly from the cloud, allowing for rapid deployment without delays, expenses, or extended outage. This minimizes or even eliminates the need for huge, complicated data centers and lets users to access the applications they require from anywhere in the world, not just the workplace.
#
# ## Disadvantages of Using Salesforce Dashboards
#
# 1. Dashboards can only be created from matrix and summary reports.
# <br>
#
# 2. A report displays a maximum of 2,000 rows. To view all rows, you need to export the report to Excel or use the printable view for tabular and summary reports. However, for joined reports, the export option is not available, and the printable view displays a maximum of 20,000 rows.
# <br>
#
# 3. In the report builder, up to 20 rows are displayed for summary and matrix reports and up to 50 rows for tabular reports. You can use a maximum of five formulas per report.
# <br>
#
# 4. You can use up to 20 field filters in a report.
# <br>
#
# 5. To set the maximum number of records to display in a tabular report, you need to select Row Limit in a report builder.
# <br>
#
# 6. By default, reports timeout after 10 minutes. You can contact Salesforce.com support to extend the time-out limit to 20 minutes for tabular, summary, and matrix reports, but no extension is available for joined reports.
# <br>
#
# 7. Reports will only show the first 254 characters in a rich-text area or a long-text area.

# %% [markdown]
# # Reflective Evaluation
#
# At the start of the project, designing and data analysis were difficult tasks. Everything began with locating an accurate dataset and a project topic. Finding the dataset took a long time since many of them did not have the needed data or had too many entries, necessitating additional cleaning and filtration. After locating the relevant dataset, conducting research on the issue of income trends and budgeting proved difficult.
#
# There is a lot of data accessible, and collecting data that is exact enough for this project and then merging the data for better evaluation is a challenge. Finding the most accurate visualizations was quite simple, as was learning graph representation in Python and Dash Python. The most crucial duty was assembling all of the data into a report, which was not a simple undertaking. The report's wording was carefully crafted, as were the statistics, headers, visualizations, and graphics.
#
# Finally, a lot of learning, a lot of skills, and real-time management were obtained. Developing problem-solving abilities, design abilities, data assessment, mistake detection and correction, learning new code, comparing and analyzing different data visualization methods in real time.

# %% [markdown]
# # Conclusion
#
# To summarize the complete study, it discusses all of the income patterns throughout the world based on the many parameters provided in the datasets. We also analyzed and compared various visualizations and discussed why salaries are rising in comparison to previous years, what factors are driving increased demand for money in all businesses for their employees for salary budget allocation amongst the 15 largest world economies, how are these firms fighting for the greatest talent available, and what HR professionals and management can do to recruit more talent while still retaining their own employees? The organization's reputation is also significant in many ways, such as staying at the top of the list, competing against the world's greatest firms, and growing with technology and time.
#
# In the midst of uncertainty and the possibility of a recession, HR and pay professionals must balance the necessity for higher salaries owing to inflation and labor market issues with the danger of expanding permanent cost structures. While a recession is imminent, its duration and magnitude are unknown. Despite these challenges, companies should maintain their cool and take a cautious approach that is in line with market realities and defined corporate goals. It is impossible to respond to all market developments at the same time. The best place to start is with trustworthy market data that can assist essential and defensible decision-making.
#
# #### The way the companies are trying to improve their compensation packages are:
#
# <b>Increased staff Retention:</b> increased salary is closely related to increased staff retention rates. According to a Harvard University research, a 1 dollar per hour pay boost resulted in a 2.8% increase in retention while 1 dollar per hour pay decline resulted in a 28% rise in turnover rates.
#
# <b>Long-term Planning:</b> The talent shortfall is anticipated to worsen, with a worldwide talent shortage of more than 85 million workers predicted by 2030. Preparing your firm for future workforce demands is critical now.
#
# <b>Savings:</b> If done appropriately, a wage raise may pay for itself and deliver a high ROI. Identifying the best remuneration package can result in cost savings from reduced overtime pay, fewer absenteeism, and cheaper hiring expenses.
#
# <b>Better Hiring Results:</b> Despite best efforts, 100% staff retention is not possible. A attractive wage and benefits package can help attract suitable individuals and persuade them to accept job offers when the labor shortage rises and the skills gap deepens.

# %% [markdown]
# # References
#
# White, N. (2023, September 11). Average weekly earnings in Great Britain - Office for National Statistics. https://www.ons.gov.uk/employmentandlabourmarket/peopleinwork/employmentandemployeetypes/bulletins/averageweeklyearningsingreatbritain/september2023
#
# Salary Trends 2023-24: Are local pay awards showing signs of recovery? (n.d.-b). https://www.eca-international.com/insights/blog/november-2023/salarytrends-23-24-local-pay-awards-signs-recovery
#
# Adrjan, P. (2023, July 3). Global wage growth: up in the UK, steady in the euro area, slowing in the US - indeed hiring lab UK I Ireland. Indeed Hiring Lab UK I Ireland. https://www.hiringlab.org/uk/blog/2023/06/07/global-wage-growth-up-in-the-uk/
#
# Gradar. (2023, January 30). Keeping it competitive: The importance of salary benchmarking. https://www.linkedin.com/pulse/keeping-competitive-importance-salary-benchmarking-gradar/
#
# Uk, R., & Uk, R. (n.d.). Randstad UK. https://www.randstad.co.uk/market-insights/attracting-recruiting-talent/impact-compensation-benefits-employee-retention/
#
# White, N. (2021, April 19). Average weekly earnings in Great Britain - Office for National Statistics. https://www.ons.gov.uk/employmentandlabourmarket/peopleinwork/employmentandemployeetypes/bulletins/averageweeklyearningsingreatbritain/april2021
#
# 2023 employee pay trends. (2023, January 20). WTW. https://www.wtwco.com/en-gb/insights/2023/01/2023-employee-pay-trends
#
# Object creator. (n.d.). https://object-creator.salesforce.com/load-data-wizard.xhtml
#
# Kps3admin. (2023, October 26). Salesforce Dashboards. Accounting Seed. https://www.accountingseed.com/resource/blog/salesforce-dashboards/
#
# Help and training community. (n.d.). Salesforce. https://help.salesforce.com/s/articleView?id=sf.rd_reports_dashboards_limits_overview.htm&type=5
#
# Squared, I. (2021, September 20). Salesforce reports and limitations of SFDC. InsightSquared. https://www.insightsquared.com/blog/the-limitations-of-salesforce-com-reports/
